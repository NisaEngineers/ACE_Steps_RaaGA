# %%
# %cd /content
# !git clone https://github.com/NisaEngineers/ACE_Steps_RaaGA.git
# %cd /content/ACE_Steps_RaaGA
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'ACE_Steps_RaaGA'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 59 (delta 4), reused 55 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (59/59), 191.45 KiB | 19.14 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/ACE_Steps_RaaGA
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 52.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 39.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 125.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.2 MB/s eta 0:00:00
# ...

# %%
# Remove old installs
# !pip uninstall -y transformers diffusers peft accelerate

# Reinstall fresh
# !pip install git+https://github.com/huggingface/transformers.git
# !pip install git+https://github.com/huggingface/diffusers.git
# !pip install git+https://github.com/huggingface/peft.git
# !pip install accelerate
# Out:
# Found existing installation: transformers 4.50.0
# Uninstalling transformers-4.50.0:
#   Successfully uninstalled transformers-4.50.0
# Found existing installation: diffusers 0.32.2
# Uninstalling diffusers-0.32.2:
#   Successfully uninstalled diffusers-0.32.2
# Found existing installation: peft 0.18.0
# Uninstalling peft-0.18.0:
#   Successfully uninstalled peft-0.18.0
# Found existing installation: accelerate 1.6.0
# Uninstalling accelerate-1.6.0:
#   Successfully uninstalled accelerate-1.6.0
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-qqvolh2h
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-qqvolh2h
#   Resolved https://github.com/huggingface/transformers.git to commit 0fa49db1205e0a2745161ccac46184e7e46b6e2b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install torchaudio

# %%
# !rm -rf /content/ACE_Steps_RaaGA

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/NisaEngineers/ACE_Steps_RaaGA.git
# Out:
# Cloning into 'ACE_Steps_RaaGA'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 62 (delta 6), reused 54 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 192.42 KiB | 21.38 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# !pip install torchcodec
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 89.1 MB/s eta 0:00:00
# ...

# %%
# %cd /content/ACE_Steps_RaaGA

# !python app.py --checkpoint_path ACE-Step/ACE-Step-v1-3.5B --port 7865 --device_id 0 --share --bf16
# Out:
# /content/ACE_Steps_RaaGA
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# ...
